# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
session = Session(engine)

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
session.query(Measurement.date, Measurement.tobs).filter(extract('month',Measurement.date)==6).all()
# Out:
# [('2010-06-01', 78.0),
#  ('2010-06-02', 76.0),
#  ('2010-06-03', 78.0),
#  ('2010-06-04', 76.0),
#  ('2010-06-05', 77.0),
#  ('2010-06-06', 78.0),
#  ('2010-06-07', 77.0),
#  ('2010-06-08', 78.0),
#  ('2010-06-09', 78.0),
#  ('2010-06-10', 79.0),
#  ('2010-06-11', 78.0),
#  ('2010-06-12', 78.0),
#  ('2010-06-13', 78.0),
#  ('2010-06-14', 77.0),
#  ('2010-06-15', 78.0),
#  ('2010-06-16', 78.0),
#  ('2010-06-17', 77.0),
#  ('2010-06-18', 77.0),
#  ('2010-06-19', 82.0),
#  ('2010-06-20', 78.0),
#  ('2010-06-21', 78.0),
#  ('2010-06-22', 78.0),
#  ('2010-06-23', 78.0),
#  ('2010-06-24', 78.0),
#  ('2010-06-25', 77.0),
#  ('2010-06-26', 76.0),
#  ('2010-06-27', 78.0),
#  ('2010-06-28', 78.0),
#  ('2010-06-29', 78.0),
#  ('2010-06-30', 78.0),
#  ('2011-06-01', 77.0),
#  ('2011-06-02', 78.0),
#  ('2011-06-03', 73.0),
#  ('2011-06-04', 70.0),
#  ('2011-06-05', 76.0),
#  ('2011-06-06', 77.0),
#  ('2011-06-07', 77.0),
#  ('2011-06-08', 77.0),
#  ('2011-06-09', 77.0),
#  ('2011-06-10', 78.0),
# ...

# %%
#  3. Convert the June temperatures to a list.
results = session.query(Measurement.date, Measurement.tobs).filter(extract('month',Measurement.date)==6).all()

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
df = pd.DataFrame(results, columns=['date','temperature'])
df.set_index(df['date'], inplace=True)

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
df.describe()
# Out:
#        temperature
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
session.query(Measurement.date, Measurement.tobs).filter(extract('month',Measurement.date)==12).all()
# Out:
# [('2010-12-01', 76.0),
#  ('2010-12-03', 74.0),
#  ('2010-12-04', 74.0),
#  ('2010-12-06', 64.0),
#  ('2010-12-07', 64.0),
#  ('2010-12-08', 67.0),
#  ('2010-12-09', 77.0),
#  ('2010-12-10', 66.0),
#  ('2010-12-11', 69.0),
#  ('2010-12-12', 68.0),
#  ('2010-12-13', 68.0),
#  ('2010-12-14', 71.0),
#  ('2010-12-15', 74.0),
#  ('2010-12-16', 67.0),
#  ('2010-12-17', 66.0),
#  ('2010-12-18', 69.0),
#  ('2010-12-19', 71.0),
#  ('2010-12-23', 70.0),
#  ('2010-12-24', 70.0),
#  ('2010-12-26', 74.0),
#  ('2010-12-27', 74.0),
#  ('2010-12-28', 71.0),
#  ('2010-12-29', 75.0),
#  ('2010-12-30', 75.0),
#  ('2010-12-31', 72.0),
#  ('2011-12-01', 69.0),
#  ('2011-12-02', 68.0),
#  ('2011-12-03', 73.0),
#  ('2011-12-04', 74.0),
#  ('2011-12-05', 73.0),
#  ('2011-12-06', 73.0),
#  ('2011-12-07', 73.0),
#  ('2011-12-08', 73.0),
#  ('2011-12-09', 71.0),
#  ('2011-12-10', 73.0),
#  ('2011-12-11', 73.0),
#  ('2011-12-12', 77.0),
#  ('2011-12-13', 72.0),
#  ('2011-12-14', 71.0),
#  ('2011-12-15', 73.0),
# ...

# %%
# 7. Convert the December temperatures to a list.
results = session.query(Measurement.date, Measurement.tobs).filter(extract('month',Measurement.date)==12).all()

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
df = pd.DataFrame(results, columns=['date', 'temperature'])
df.set_index(df['date'], inplace=True)

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
df.describe()
# Out:
#        temperature
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000

# %%
################################################################################

# %% [markdown]
# ## D3: Provide a two additional queries that would perform gather more weather data for June and December

# %%
 ### Providing two additional queries that you would perform to gather more weather data for June and December.

# %%
### First query related to the precipitation as a aditional information

# %%
engine = create_engine("sqlite:///hawaii.sqlite")



# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Dependencies
import numpy as np
import pandas as pd
import datetime as dt

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")



# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
session = Session(engine)

# %%
# query date and precipitation columns
results = session.query(Measurement.date, Measurement.prcp).all()

# %%
# 1 Write a query that filters the Measurement table to retrieve the precipitation for the month of June.
from sqlalchemy import extract
session.query(Measurement.date, Measurement.prcp).filter(extract('month',Measurement.date)==6).all()
# Out:
# [('2010-06-01', 0.0),
#  ('2010-06-02', 0.01),
#  ('2010-06-03', 0.0),
#  ('2010-06-04', 0.0),
#  ('2010-06-05', 0.0),
#  ('2010-06-06', 0.0),
#  ('2010-06-07', 0.0),
#  ('2010-06-08', 0.0),
#  ('2010-06-09', 0.0),
#  ('2010-06-10', 0.0),
#  ('2010-06-11', 0.0),
#  ('2010-06-12', 0.0),
#  ('2010-06-13', 0.0),
#  ('2010-06-14', 0.0),
#  ('2010-06-15', 0.0),
#  ('2010-06-16', 0.0),
#  ('2010-06-17', 0.0),
#  ('2010-06-18', 0.0),
#  ('2010-06-19', 0.0),
#  ('2010-06-20', 0.0),
#  ('2010-06-21', 0.0),
#  ('2010-06-22', 0.0),
#  ('2010-06-23', 0.0),
#  ('2010-06-24', 0.0),
#  ('2010-06-25', 0.0),
#  ('2010-06-26', 0.02),
#  ('2010-06-27', 0.0),
#  ('2010-06-28', 0.0),
#  ('2010-06-29', 0.0),
#  ('2010-06-30', 0.0),
#  ('2011-06-01', 0.07),
#  ('2011-06-02', 0.0),
#  ('2011-06-03', 0.56),
#  ('2011-06-04', 0.89),
#  ('2011-06-05', 0.0),
#  ('2011-06-06', 0.0),
#  ('2011-06-07', 0.0),
#  ('2011-06-08', 0.03),
#  ('2011-06-09', 0.01),
#  ('2011-06-10', 0.0),
#  ('2011-06-11', 0.0),
# ...

# %%
# retrieve the precipitation for the month of June
df = pd.DataFrame(results, columns=['date','precipitation'])
df.set_index(df['date'], inplace=True)

df = df.sort_index()
df_june = df['2010-06-01':'2016-06-30']

# %%
df_june.describe()
# Out:
#        precipitation
# count   14760.000000
# mean        0.158264
# std         0.464428
# min         0.000000
# 25%         0.000000
# 50%         0.010000
# 75%         0.100000
# max        11.530000

# %%
# 2. Write a query that filters the Measurement table to retrieve the precipitation for the month of December. 
from sqlalchemy import extract
session.query(Measurement.date, Measurement.prcp).filter(extract('month',Measurement.date)==12).all()
# Out:
# [('2010-12-01', 0.04),
#  ('2010-12-03', 0.0),
#  ('2010-12-04', 0.0),
#  ('2010-12-06', 0.0),
#  ('2010-12-07', 0.0),
#  ('2010-12-08', 0.0),
#  ('2010-12-09', 0.0),
#  ('2010-12-10', 1.58),
#  ('2010-12-11', 0.77),
#  ('2010-12-12', 0.0),
#  ('2010-12-13', 0.0),
#  ('2010-12-14', 0.0),
#  ('2010-12-15', 0.0),
#  ('2010-12-16', 0.0),
#  ('2010-12-17', 0.0),
#  ('2010-12-18', 0.0),
#  ('2010-12-19', 1.4),
#  ('2010-12-23', 0.0),
#  ('2010-12-24', 0.0),
#  ('2010-12-26', None),
#  ('2010-12-27', 0.13),
#  ('2010-12-28', 0.55),
#  ('2010-12-29', 0.06),
#  ('2010-12-30', 0.01),
#  ('2010-12-31', 0.0),
#  ('2011-12-01', 0.03),
#  ('2011-12-02', 0.08),
#  ('2011-12-03', 0.0),
#  ('2011-12-04', 0.0),
#  ('2011-12-05', 0.0),
#  ('2011-12-06', 0.0),
#  ('2011-12-07', 0.0),
#  ('2011-12-08', 0.0),
#  ('2011-12-09', 0.13),
#  ('2011-12-10', 0.07),
#  ('2011-12-11', 0.07),
#  ('2011-12-12', 0.08),
#  ('2011-12-13', 0.4),
#  ('2011-12-14', 0.7),
#  ('2011-12-15', 0.0),
#  ('2011-12-16', 0.01),
# ...

# %%
# retrieve the precipitation for the month of December
df = pd.DataFrame(results, columns=['date','precipitation'])
df.set_index(df['date'], inplace=True)

df = df.sort_index()
df_dec = df['2010-12-01':'2016-12-31']

# %%
df_dec.describe()
# Out:
#        precipitation
# count   14385.000000
# mean        0.169073
# std         0.491953
# min         0.000000
# 25%         0.000000
# 50%         0.010000
# 75%         0.110000
# max        11.530000

# %%
### Second query related to the frequency of temperature in the station with highest observations as a aditional information
### Related to Jun, 2016

# %%
# How many stations are available in this dataset?
session.query(func.count(Station.station)).all()
# Out:
# [(9)]

# %%
session.query(Measurement.station, func.count(Measurement.station)).\
    group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# frequency of temperature in the station with highest observations in June month 

import datetime as dt
from pandas.plotting import table
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

results = session.query(Measurement.tobs).\
    filter(Measurement.station == 'USC00519281').\
    filter(Measurement.station >= '2016-06-01').\
    filter(Measurement.date <= '2016-06-30').all()
df = pd.DataFrame(results, columns=['tobs'])
df.plot.hist(bins=12)
plt.title('Temperature June vs frequency by USC00519281 Station')
plt.xlabel('Temperatura in fahrenheit degree')
plt.tight_layout()

# %%
### Second query related to the frequency of temperature in the station with highest observations as a aditional information
### Related to Dec, 2016

# %%
# frequency of temperature in the station with highest observations in December month

import datetime as dt
from pandas.plotting import table
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

results = session.query(Measurement.tobs).\
    filter(Measurement.station == 'USC00519281').\
    filter(Measurement.station >= '2016-12-01').\
    filter(Measurement.date <= '2016-12-31').all()
df = pd.DataFrame(results, columns=['tobs'])
df.plot.hist(bins=12)
plt.title('Temperature Dec vs frequency by USC00519281 Station')
plt.xlabel('Temperatura in fahrenheit degree')
plt.tight_layout()
